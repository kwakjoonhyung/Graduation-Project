# 3        NaN       NaN       NaN       NaN       NaN       NaN
# 4   0.000514  0.000003  0.000003  0.000008  0.000925  0.000003
# 5   0.000791  0.000791  0.005757  0.005803  0.001680  0.000791
# 6   0.002310  0.000085  0.000085  0.000180  0.003356  0.000085
# 7   0.000231  0.000231  0.009763  0.009692  0.004265  0.000231
# 8   0.003070  0.001325  0.006691  0.003152  0.015824  0.001325
# 9   0.001251  0.001251  0.005404  0.025211  0.001291  0.003546
# 10  0.004474  0.001075  0.001075  0.001075  0.047783  0.001075
# 11  0.000018  0.000009  0.001797  0.022274  0.000574  0.000009
# 12  0.005974  0.000287  0.000287  0.003915  0.006648  0.000287
# 13  0.004242  0.047643  0.002023  0.006725  0.002023  0.002023
# 14  0.001696  0.000378  0.000378  0.000378  0.058112  0.019982
# 15  0.003260  0.003845  0.003260  0.003260  0.003260  0.003260
# 16       NaN       NaN       NaN       NaN       NaN       NaN
#
# [17 rows x 149 columns]

# %%
df.iloc[3].values
# Out:
# array([0.01981949, 0.05422599, 0.00428008, 0.00193378, 0.00193378,
#        0.00487583, 0.00257878, 0.00469577, 0.00193378, 0.0146193 ,
#        0.00193378, 0.01005371, 0.00404853, 0.00210121, 0.00439729,
#        0.00193378, 0.01373271, 0.00193378, 0.00193378, 0.00193378,
#        0.02067443, 0.01955441, 0.00514767, 0.00193378, 0.00193378,
#        0.00234923, 0.00193378, 0.00193378, 0.00193378, 0.00193378,
#        0.00193378, 0.00233851, 0.00193378, 0.00193378, 0.00219585,
#        0.00193378, 0.01848065, 0.00558504, 0.00232094, 0.00193378,
#        0.00193378, 0.00193378, 0.00193378, 0.09541421, 0.00762215,
#        0.00193378, 0.00308979, 0.00193378, 0.00193378, 0.0023344 ,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan,        nan,
#               nan,        nan,        nan,        nan])

# %%
filtered_arr = df.iloc[3].values[~np.isnan(df.iloc[3].values)]
filtered_arr
# Out:
# array([0.01981949, 0.05422599, 0.00428008, 0.00193378, 0.00193378,
#        0.00487583, 0.00257878, 0.00469577, 0.00193378, 0.0146193 ,
#        0.00193378, 0.01005371, 0.00404853, 0.00210121, 0.00439729,
#        0.00193378, 0.01373271, 0.00193378, 0.00193378, 0.00193378,
#        0.02067443, 0.01955441, 0.00514767, 0.00193378, 0.00193378,
#        0.00234923, 0.00193378, 0.00193378, 0.00193378, 0.00193378,
#        0.00193378, 0.00233851, 0.00193378, 0.00193378, 0.00219585,
#        0.00193378, 0.01848065, 0.00558504, 0.00232094, 0.00193378,
#        0.00193378, 0.00193378, 0.00193378, 0.09541421, 0.00762215,
#        0.00193378, 0.00308979, 0.00193378, 0.00193378, 0.0023344 ])

# %%
# Create an array of time steps
time_steps = np.arange(len(df.iloc[3].values))

# Plot the attention weights as a bar graph
plt.bar(time_steps, df.iloc[3].values)
plt.xlabel('Time steps')
plt.ylabel('Attention weights')
plt.show()
# Save the figure as an image
# plt.savefig(f'attention_bargraph_{current_time}.png', dpi=300, bbox_inches='tight')

# %%
def max_sum_subarray(arr, window_size):
    # Number of elements in array
    n = len(arr)
    
    # If window size is larger than array size
    if (window_size > n):
        return "Invalid: Window size is larger than array size."
    
    # Compute the initial window sum
    window_sum = sum([arr[i] for i in range(window_size)])
    max_sum = window_sum
    max_start = 0
    
    # Slide the window
    for i in range(n - window_size):
        window_sum = window_sum - arr[i] + arr[i + window_size]
        
        # Update the maximum sum and the starting index of max_sum
        if window_sum > max_sum:
            max_sum = window_sum
            max_start = i + 1
    
    return (max_start, max_start + window_size, max_sum)

# %%
def max_sum_pattern_pad(arr, window_size):
    # Number of elements in array
    n1 = len(arr)
    
    # If window size is larger than array size
    if (window_size > n1):
        pad_size = window_size - n1
        mini_window_size = pad_size
        mini_start, _, mini_sum = max_sum_subarray(arr, mini_window_size)
        arr = np.pad(arr, (0, pad_size), 'constant', constant_values=(0))
        arr[n1:n1+pad_size] = arr[mini_start:mini_start+pad_size]
        n = len(arr)
    
    # Compute the initial window sum
    window_sum = sum([arr[i] for i in range(window_size)])
    max_sum = window_sum
    max_start = 0
    
    # Slide the window
    for i in range(n - window_size):
        window_sum = window_sum - arr[i] + arr[i + window_size]
        
        # Update the maximum sum and the starting index of max_sum
        if window_sum > max_sum:
            max_sum = window_sum
            max_start = i + 1
    
    return (max_start, max_start + window_size, mini_start,mini_start+pad_size,max_sum, arr,n1)

# %%
# Window size
window_size = 80

# Print the start and end index and the sum of maximum sum subarray
print(max_sum_pattern_pad(filtered_arr, window_size))
# Out:
# (0, 80, 15, 45, 0.6051045040000004, array([0.01981949, 0.05422599, 0.00428008, 0.00193378, 0.00193378,
#        0.00487583, 0.00257878, 0.00469577, 0.00193378, 0.0146193 ,
#        0.00193378, 0.01005371, 0.00404853, 0.00210121, 0.00439729,
#        0.00193378, 0.01373271, 0.00193378, 0.00193378, 0.00193378,
#        0.02067443, 0.01955441, 0.00514767, 0.00193378, 0.00193378,
#        0.00234923, 0.00193378, 0.00193378, 0.00193378, 0.00193378,
#        0.00193378, 0.00233851, 0.00193378, 0.00193378, 0.00219585,
#        0.00193378, 0.01848065, 0.00558504, 0.00232094, 0.00193378,
#        0.00193378, 0.00193378, 0.00193378, 0.09541421, 0.00762215,
#        0.00193378, 0.00308979, 0.00193378, 0.00193378, 0.0023344 ,
#        0.00193378, 0.01373271, 0.00193378, 0.00193378, 0.00193378,
#        0.02067443, 0.01955441, 0.00514767, 0.00193378, 0.00193378,
#        0.00234923, 0.00193378, 0.00193378, 0.00193378, 0.00193378,
#        0.00193378, 0.00233851, 0.00193378, 0.00193378, 0.00219585,
#        0.00193378, 0.01848065, 0.00558504, 0.00232094, 0.00193378,
#        0.00193378, 0.00193378, 0.00193378, 0.09541421, 0.00762215]), 50)

# %%
start, end,m_start,m_end, _,arr,length = max_sum_pattern_pad(filtered_arr, window_size)

# Create an array of time steps
time_steps = np.arange(len(arr))

# Plot the attention weights as a bar graph
plt.figure(figsize=(10,6))
plt.bar(time_steps, arr, color='lightgray')
plt.bar(time_steps[m_start:m_end],arr[m_start:m_end], color='orange')
plt.bar(time_steps[length:],arr[length:], color='orange')

plt.xlabel('Time steps')
plt.ylabel('Attention weights')
plt.title('Attention Weights with Max Sum Subarray with local pattern padding Highlighted')

plt.show()
